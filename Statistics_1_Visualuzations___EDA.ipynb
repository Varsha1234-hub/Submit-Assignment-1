# %% [markdown]
# # Statistics - Exploratory Data Analysis
#
# .Histogram plots
#
# .Scatter plots
#
# .Percentiles
#
# .Boxplots
#
# .Violin
#
# .Heatmaps
#
# .Barplots
#
# .Factor plots
#
# .Density plots
#
# .Joint Distribution plots

# %%
import pandas as pd
import numpy as np
file_name = "/content/winequalityN.csv"
df = pd.read_csv(file_name)
df.head()
# Out:
#     type  fixed acidity  volatile acidity  ...  sulphates  alcohol  quality
# 0  white            7.0              0.27  ...       0.45      8.8        6
# 1  white            6.3              0.30  ...       0.49      9.5        6
# 2  white            8.1              0.28  ...       0.44     10.1        6
# 3  white            7.2              0.23  ...       0.40      9.9        6
# 4  white            7.2              0.23  ...       0.40      9.9        6
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Simple Descriptive Analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    6487.000000       6489.000000  ...  6497.000000  6497.000000
# mean        7.216579          0.339691  ...    10.491801     5.818378
# std         1.296750          0.164649  ...     1.192712     0.873255
# min         3.800000          0.080000  ...     8.000000     3.000000
# 25%         6.400000          0.230000  ...     9.500000     5.000000
# 50%         7.000000          0.290000  ...    10.300000     6.000000
# 75%         7.700000          0.400000  ...    11.300000     6.000000
# max        15.900000          1.580000  ...    14.900000     9.000000
#
# [8 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df["alcohol"].mean()
# Out:
# 10.491800831149511

# %%
df["sulphates"].mean()
# Out:
# 0.5312151547820745

# %%
df["alcohol"].median()
# Out:
# 10.3

# %%
df["alcohol"].sum()
# Out:
# 68165.22999997801

# %% [markdown]
# Let's plot using Histogram

# %%
df.hist(column='alcohol', bins=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f277bf4dc18>]],
#       dtype=object)

# %%
# Let's get a bit more advanced and learn to customize your plots
df.hist(column='alcohol', bins=10, grid=False, figsize=(10,6), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f03071125f8>]],
#       dtype=object)

# %%
df.hist(column='sulphates', bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f030706bef0>]],
#       dtype=object)

# %% [markdown]
# # **These look nice, but using the library Seaborn, we can quickly produce even nicer plots**

# %%
import seaborn as sns
sns.distplot(df['alcohol'], bins=25, kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
sns.distplot(df['alcohol'], bins=25, kde=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df.alcohol, bins=10, kde=True, color="red")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df["alcohol"].value_counts().head()
# Out:
# 9.5     367
# 9.4     332
# 9.2     271
# 10.0    229
# 10.5    227
# Name: alcohol, dtype: int64

# %%
df["alcohol"].value_counts().describe()
# Out:
# count    111.000000
# mean      58.531532
# std       81.888707
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%      106.500000
# max      367.000000
# Name: alcohol, dtype: float64

# %%
df["sulphates"].value_counts().head()
# Out:
# 0.50    275
# 0.46    243
# 0.54    234
# 0.44    232
# 0.38    214
# Name: sulphates, dtype: int64

# %% [markdown]
# Styling and Axis Labels

# %%
# Let's start with labeling our axis
import matplotlib.pyplot as plt
_ = sns.distplot(df.alcohol)
_ = plt.xlabel('Alcohol Percentage')
_ = plt.ylabel('Count')
_ = plt.title("Alcohol Content")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Use sns.set_style() to control styling
sns.set_style("dark")
sns.distplot(df.alcohol, bins=15)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Use sns.set_style() to control styling
sns.set_style("ticks")
sns.distplot(df.sulphates, bins=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Scatter Plot

# %%
sns.lmplot(x='alcohol', y='fixed acidity', data=df)

# %%
sns.lmplot(x='alcohol', y='density', data=df, fit_reg=False)

# %%
# Scatterplot arguments
sns.lmplot(x='alcohol', y='chlorides', data=df,
 fit_reg=False, # Remove the regression line
 hue='quality') # Color by quality

# %% [markdown]
# ## Understanding Percentiles

# %%
# The quantile function
print(df["alcohol"].quantile(0.1))
print(df["alcohol"].quantile(0.5))
print(df["alcohol"].quantile(0.9))
print(df["alcohol"].quantile(0.99))
# Out:
# 9.1
# 10.3
# 12.3
# 13.4

# %%
# The quantile function
print(df["sulphates"].quantile(0.12))
print(df["sulphates"].quantile(0.55))
print(df["sulphates"].quantile(0.91))
print(df["sulphates"].quantile(0.99))
# Out:
# 0.38
# 0.52
# 0.73
# 0.99

# %%
# What's the max alcohol value though?
df["alcohol"].max()
# Out:
# 14.9

# %%
# What's the max sulphates value though?
df["sulphates"].max()
# Out:
# 2.0

# %%
# What's the min alcohol value though?
df["alcohol"].min()
# Out:
# 8.0

# %%
# Quantile ranges
df["alcohol"].quantile(([0.05, 0.95]))
# Out:
# 0.05     9.0
# 0.95    12.7
# Name: alcohol, dtype: float64

# %%
# Quantile ranges
df["alcohol"].quantile(([0.1, 0.95]))
# Out:
# 0.10     9.1
# 0.95    12.7
# Name: alcohol, dtype: float64

# %%
# Quantile ranges
df["sulphates"].quantile(([0.5, 0.95]))
# Out:
# 0.50    0.51
# 0.95    0.79
# Name: sulphates, dtype: float64

# %% [markdown]
# ## Boxplots And Finding Outliers

# %%
print(df["alcohol"].quantile(([0.25, 0.75])))
sns.boxplot(data=df['alcohol'])
# Out:
# 0.25     9.5
# 0.75    11.3
# Name: alcohol, dtype: float64

# %%
sns.boxplot(data=df, palette="Set3")

# %%
from matplotlib import pyplot as plt
# Enlarge the plot
plt.figure(figsize=(12,8))
summary = df.drop(['free sulfur dioxide', 'total sulfur dioxide', 'quality',
 'residual sugar', 'fixed acidity', 'alcohol'], axis=1)
sns.boxplot(data=summary, palette="Set3")

# %% [markdown]
# ## Violin Plots

# %%
sns.violinplot(data=df['alcohol'])

# %%
sns.violinplot(data=df['sulphates'])

# %%
# Bar Plot
# Enlarge the plot
plt.figure(figsize=(12,8))
sns.countplot(x='quality', data=df, hue='type')

# %%
# Titanic Example
sns.set(style="whitegrid")
# Load the example Titanic dataset
titanic = sns.load_dataset("titanic")
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="class", y="survived", hue="sex", data=titanic,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("survival probability")

# %%
# Density Plot
sns.kdeplot(df.alcohol, df.density)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Density Plot
sns.kdeplot(df.sulphates, df.density)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Joint Distribution Plot
sns.jointplot(x='alcohol', y='density', data=df)

# %% [markdown]
# ## Factor plots allow us to create separate plots by categorical classes.
#
#
# Factor Plots and Bee Swarm Plots

# %%
# Factor Plot
g = sns.factorplot(x='free sulfur dioxide',
 y='alcohol',
 data=df,
 # A recent update in Matplotlib broke how the hue argument works in S
 #hue='quality', # Color by stage
 col='quality', # Separate by stage
 kind='point') # Swarmplot
# Rotate x-axis labels
g.set_xticklabels(rotation=-45)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ## Creating Empirical cumulative distribution function (ECDF)

# %%
import numpy as np
x = np.sort(df['alcohol'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
plt.margins(0.05)
_ = plt.xlabel('Percent of Alcohol in Wine')
_ = plt.ylabel('ECDF')
plt.grid(True)
plt.show()

# %%
print(df["alcohol"].quantile(([0.2, 0.8])))
# Out:
# 0.2     9.4
# 0.8    11.5
# Name: alcohol, dtype: float64

# %%
print(df["sulphates"].quantile(([0.1, 0.9])))
# Out:
# 0.1    0.37
# 0.9    0.72
# Name: sulphates, dtype: float64
